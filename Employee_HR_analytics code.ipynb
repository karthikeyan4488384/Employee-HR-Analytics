# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0f497841-7a87-442a-9fa3-c6d5ddd1c720" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0f497841-7a87-442a-9fa3-c6d5ddd1c720">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("employeedata.csv")
df.head()
# Out:
#   EmpID    Name Department Gender  Age  Experience_Years   Salary   Join_Date  \
# 0  E101    Arun         IT      M   25                 2  40000.0  2021-06-15
# 1  E102    Bala         HR      M   28                 4  50000.0  2019-03-20
# 2  E103  Chitra    Finance      F   32                 7  65000.0  2017-11-05
# 3  E104   Deepa         IT      F   29                 5  58000.0  2018-08-12
# 4  E105   Ezhil      Sales      M   35                10      NaN  2015-01-10
#
#    Performance_Rating
# 0                   3
# 1                   4
# 2                   5
# 3                   4
# 4                   5

# %%
print("===== Dataset Info =====")
print(df.info())

print("\n===== Missing Values =====")
print(df.isna().sum())
# Out:
# ===== Dataset Info =====
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EmpID               10 non-null     object
#  1   Name                10 non-null     object
#  2   Department          10 non-null     object
#  3   Gender              10 non-null     object
#  4   Age                 10 non-null     int64
#  5   Experience_Years    10 non-null     int64
#  6   Salary              10 non-null     float64
#  7   Join_Date           10 non-null     datetime64[ns]
#  8   Performance_Rating  10 non-null     int64
#  9   Tenure_Years        10 non-null     int32
#  10  Salary_Band         10 non-null     object
# dtypes: datetime64[ns](1), float64(1), int32(1), int64(3), object(5)
# memory usage: 972.0+ bytes
# None
#
# ===== Missing Values =====
# EmpID                 0
# Name                  0
# ...

# %%
# Fill missing Salary with mean
df["Salary"] = df["Salary"].fillna(df["Salary"].mean())

# Convert Join_Date to datetime.
df["Join_Date"] = pd.to_datetime(df["Join_Date"])

print("===== After Cleaning =====")
print(df.isna().sum())
# Out:
# ===== After Cleaning =====
# EmpID                 0
# Name                  0
# Department            0
# Gender                0
# Age                   0
# Experience_Years      0
# Salary                0
# Join_Date             0
# Performance_Rating    0
# Tenure_Years          0
# Salary_Band           0
# dtype: int64

# %%
# Create Tenure column
df["Tenure_Years"] = 2024 - df["Join_Date"].dt.year

# Create Salary Band
df["Salary_Band"] = df["Salary"].apply(
    lambda x: "Low" if x < 45000 else "Medium" if x < 60000 else "High"
)

df[["Name", "Salary", "Salary_Band", "Tenure_Years"]].head()
# Out:
#      Name   Salary Salary_Band  Tenure_Years
# 0    Arun  40000.0         Low             3
# 1    Bala  50000.0      Medium             5
# 2  Chitra  65000.0        High             7
# 3   Deepa  58000.0      Medium             6
# 4   Ezhil  54000.0      Medium             9

# %%
avg_salary = df.groupby("Department")["Salary"].mean()
avg_experience = df.groupby("Department")["Tenure_Years"].mean()
avg_performance = df.groupby("Department")["Performance_Rating"].mean()

print("Average Salary:\n", avg_salary)
print("\nAverage Experience:\n", avg_experience)
print("\nAverage Performance:\n", avg_performance)
# Out:
# Average Salary:
#  Department
# Finance    59500.000000
# HR         49000.000000
# IT         52666.666667
# Sales      58000.000000
# Name: Salary, dtype: float64
#
# Average Experience:
#  Department
# Finance    5.500000
# HR         4.333333
# IT         4.666667
# Sales      8.500000
# Name: Tenure_Years, dtype: float64
#
# Average Performance:
#  Department
# Finance    4.000000
# HR         4.000000
# IT         3.666667
# Sales      4.500000
# Name: Performance_Rating, dtype: float64

# %%
strong_dept = avg_performance.idxmax()
print("Strongest Department (by performance):", strong_dept)
# Out:
# Strongest Department (by performance): Sales

# %%
retention_risk = df[
    (df["Performance_Rating"] <= 2) &
    (df["Tenure_Years"] >= 5)]

retention_risk[["Name", "Department", "Tenure_Years", "Performance_Rating"]]
# Out:
# Empty DataFrame
# Columns: [Name, Department, Tenure_Years, Performance_Rating]
# Index: []

# %%
promotion_ready = df[
    (df["Tenure_Years"] >= 6) &
    (df["Performance_Rating"] >= 4) &
    (df["Salary_Band"] != "High")
]

promotion_ready[["Name", "Department", "Tenure_Years", "Salary_Band"]]
# Out:
#      Name Department  Tenure_Years Salary_Band
# 3   Deepa         IT             6      Medium
# 4   Ezhil      Sales             9      Medium
# 9  Janani         HR             6      Medium

# %%
salary_array = df["Salary"].to_numpy()

print("Max Salary:", np.max(salary_array))
print("Min Salary:", np.min(salary_array))
print("Average Salary:", np.mean(salary_array))
# Out:
# Max Salary: 65000.0
# Min Salary: 40000.0
# Average Salary: 54000.0

# %%
#  Final Insights

#- The Sales department is strongest overall based on performance and experience.
#- Salary imbalance observed among high-tenure employees in medium salary bands.
#- Employees with low performance and long tenure pose retention risks.
#- Promotion-ready candidates identified using performance and tenure metrics.
#- This analysis supports data-driven HR decision-making.
